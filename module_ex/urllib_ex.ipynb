# %%
import urllib.request 
import urllib.parse 
value = '한글'

#parse모듈을 사용해 한글("한글")변수를 유니코드로 치환 
encode = urllib.parse.quote_plus(value) 

#한글을 제외한 주소를 url1에 저장 
url = 'https://127.0.0.1:8000/search?keyword='+encode+'&limit=50'
print(url)

#urlopen 모듈로 불러오기 
#response = urllib.request.urlopen(url)
# Out:
# https://127.0.0.1:8000/search?keyword=%ED%95%9C%EA%B8%80&limit=50

# %%
import urllib.request
f = urllib.request.urlopen('http://www.python.org/')
print(f.read(300)) # 300byte만 읽어온다.
#[출처] [Python 3.4] urllib 를 이용한 간단한 HTTP Request 및 파싱|작성자 메모리얼
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js"'

# %%
with urllib.request.urlopen('http://www.python.org/') as url:
    print(url.read(300))
    print('='*100)
    print(url.read(300).decode('utf-8'))
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js"'
# ...
#  lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">
#
#     <meta name="application-name" content="Python.org">
#     <meta name="m

# %%
import urllib.request
opener = urllib.request.build_opener()
#user-agent 헤더를 변경해서 url을 open 하는 예제
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
opener.open('http://www.python.org/')

# %%
#parameters: // GET 메서드로 parameter를 전송하는 example

import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'spam': 1, 'eggs': 2, 'bacon': 0})
f = urllib.request.urlopen("http://www.musi-cal.com/cgi-bin/query?%s" % params)
print(f.read().decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-f1efd4fd54df> in <module>
#       2 import urllib.parse
#       3 params = urllib.parse.urlencode({'spam': 1, 'eggs': 2, 'bacon': 0})
# ----> 4 f = urllib.request.urlopen("http://www.musi-cal.com/cgi-bin/query?%s" % params)
#       5 print(f.read().decode('utf-8'))
#
# c:\users\nipa\appdata\local\programs\python\python37-32\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\users\nipa\appdata\local\programs\python\python37-32\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
# ...

# %%
#POST 메서드로 parameter를 전송하는 example

import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'spam': 1, 'eggs': 2, 'bacon': 0})
data = data.encode('utf-8')
request = urllib.request.Request("http://requestb.in/xrbl82xr")
# adding charset parameter to the Content-Type header.
request.add_header("Content-Type","application/x-www-form-urlencoded;charset=utf-8")
f = urllib.request.urlopen(request, data)
print(f.read().decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\nipa\appdata\local\programs\python\python37-32\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# c:\users\nipa\appdata\local\programs\python\python37-32\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# c:\users\nipa\appdata\local\programs\python\python37-32\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
url = 'http://www.oreilly.com/temp'
print(urlparse(url).scheme)
print(urlparse(url).netloc)
print(urlparse(url).username)
# Out:
# http
# www.oreilly.com
# None

# %%
from urllib import parse
  
url = parse.urlparse('http://www.exeam.org?examParam1=value1&examParam2=한글') 

query = parse.parse_qs(url.query)
print('parse.parse_qs',query)

parse_result = parse.urlparse('https://brownbear:123@127.0.0.1:8080/path;params?name=불곰&params=123#id1') 
print(parse_result) 
print(parse_result.scheme) 
print(parse_result.username) 
print(parse_result.password) 
print(parse_result.hostname) 
print(parse_result.port) 
print('netloc :',parse_result.netloc) 
print(parse_result.path) 
print(parse_result.params) 
print(parse_result.query) 
print(parse_result.fragment)
# Out:
# parse.parse_qs {'examParam1': ['value1'], 'examParam2': ['한글']}
# ParseResult(scheme='https', netloc='brownbear:123@127.0.0.1:8080', path='/path', params='params', query='name=불곰&params=123', fragment='id1')
# https
# brownbear
# 123
# 127.0.0.1
# 8080
# netlo brownbear:123@127.0.0.1:8080
# /path
# params
# name=불곰&params=123
# id1

# %%
import urllib
from urllib import parse
a = parse.urlencode({'abc':'d f', 'def': '-!2', 'keyword' : '한글'})
print(a)
url = 'https://www.coupang.com/np/search'
params = 
#'abc=d+f&def=-%212'
# Out:
# abc=d+f&def=-%212&keyword=%ED%95%9C%EA%B8%80

# %%
import urllib
from urllib import parse
url = 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&so'
page = parse.urlparse(url)
print(page)
a = parse.parse_qs(page.query)
print(page.netloc+page.path)
print(a)

b = urllib.request.urlopen(url)
# Out:
# ParseResult(scheme='https', netloc='www.coupang.com', path='/np/search', params='', query='q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&so', fragment='')
# www.coupang.com/np/search
# {'q': ['노트북'], 'channel': ['user'], 'eventCategory': ['SRP']}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-41f8f921d38f> in <module>
#       8 print(a)
#       9
# ---> 10 b = urllib.request.urlopen(url)
#
# c:\users\nipa\appdata\local\programs\python\python37-32\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\users\nipa\appdata\local\programs\python\python37-32\lib\urllib\request.py in open(self, fullurl, data, timeout)
# ...

# %%
from bs4 import BeautifulSoup

b = urllib.request.urlopen('https://google.com')
#print(b.read())
soup = BeautifulSoup(b.read(),'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE doctype html>\n<html itemscope="" itemtype="http://schema.org/WebPage" lang="ko">\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>\n  <title>\n   Google\n  </title>\n  <script nonce="h4fR1pe0w3xM5vpXGGWI6Q==">\n   (function(){window.google={kEI:\'8ZW0X9fGEpL6-QbZ1KL4DQ\',kEXPI:\'0,202162,1100132,51452,5663,731,223,5105,206,2415,789,10,1226,364,1499,611,206,383,246,5,1354,648,3452,314,3,65,594,175,1,216,282,981,453,408,6,598,1985,590,7,695,839,284,1115170,1197713,570,7,328977,13677,4854,32693,16114,17444,11240,893,8295,8384,4858,1362,9291,3020,4747,11033,1497,311,4020,978,7933,5295,2054,918,875,4192,6430,7432,7095,4517,2778,919,2277,8,4389,1279,2212,530,149,1103,840,517,1522,4258,108,204,1137,2,2063,606,2023,1777,520,1947,2209,3,110,328,1284,16,2927,2246,1813,1787,3227,2845,7,12354,4455,641,7877,4928,108,3407,908,2,3555,2397,7470,3275,3,576,970,
# ...

# %%
from urllib import parse
print(parse.quote('한글')) #%ED%95%9C%EA%B8%80
print(parse.unquote('%ED%95%9C%EA%B8%80')) #한글
# Out:
# %ED%95%9C%EA%B8%80
# 한글

# %%
from urllib import parse
#https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=4&backgroundColor=
url = 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=4&backgroundColor='

parse_result = parse.urlparse(url) 

print(parse_result) 
print('scheme',parse_result.scheme) 
print('username',parse_result.username) 
print('password',parse_result.password) 
print('hostname',parse_result.hostname) 
print('port',parse_result.port) 
print('netloc :',parse_result.netloc) 
print('path',parse_result.path) 
print('params',parse_result.params) 
print('query',parse_result.query) 
print('fragment',parse_result.fragment)
# Out:
# ParseResult(scheme='https', netloc='www.coupang.com', path='/np/search', params='', query='q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=4&backgroundColor=', fragment='')
# scheme https
# username None
# password None
# hostname www.coupang.com
# port None
# netloc : www.coupang.com
# path /np/search
# params
# query q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=4&backgroundColor=
# fragment

# %%
a = parse.parse_qs(parse_result.query)
print(a)
b = parse.urlencode(a)
print(b)
# Out:
# {'q': ['노트북'], 'channel': ['user'], 'eventCategory': ['SRP'], 'sorter': ['scoreDesc'], 'listSize': ['36'], 'isPriceRange': ['false'], 'rating': ['0'], 'page': ['1'], 'rocketAll': ['false'], 'searchIndexingToken': ['1=4']}
# q=%5B%27%EB%85%B8%ED%8A%B8%EB%B6%81%27%5D&channel=%5B%27user%27%5D&eventCategory=%5B%27SRP%27%5D&sorter=%5B%27scoreDesc%27%5D&listSize=%5B%2736%27%5D&isPriceRange=%5B%27false%27%5D&rating=%5B%270%27%5D&page=%5B%271%27%5D&rocketAll=%5B%27false%27%5D&searchIndexingToken=%5B%271%3D4%27%5D

# %%
a['sorter']
# Out:
# ['scoreDesc']

# %%
import urllib 
# urllib 라이브러리를 불러옵니다. r = urllib.request.urlopen('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109') 
# urllib 의 request 에서 urlopen 함수를 실행하고 결과를 r에 바인딩합니다. r.read().decode('utf-8')
r = urllib.request.urlopen('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109')
# urllib 의 request 에서 urlopen 함수를 실행하고 결과를 r에 바인딩합니다. r.read().decode('utf-8')
#r.read().decode('utf-8')
r.read()
# Out:
# b'<?xml version="1.0" encoding="utf-8" ?>\r\n<rss version="2.0">\r\n<channel>\r\n<title>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad \xec\x9c\xa1\xec\x83\x81 \xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4</title>\r\n<link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>\r\n<description>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad \xeb\x82\xa0\xec\x94\xa8 \xec\x9b\xb9\xec\x84\x9c\xeb\xb9\x84\xec\x8a\xa4</description>\r\n<language>ko</language>\r\n<generator>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad</generator>\r\n<pubDate>2020\xeb\x85\x84 11\xec\x9b\x94 18\xec\x9d\xbc (\xec\x88\x98)\xec\x9a\x94\xec\x9d\xbc 06:00</pubDate>\r\n <item>\r\n<author>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad</author>\r\n<category>\xec\x9c\xa1\xec\x83\x81\xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4</category>\r\n<title>\xec\x84\x9c\xec\x9a\xb8,\xea\xb2\xbd\xea\xb8\xb0\xeb\x8f\x84 \xec\x9c\xa1\xec\x83\x81 \xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4 - 2020\xeb\x85\x84 11\xec\x9b\x94 18\xec\x9d\xbc (\xec\x88\x98)\x
# ...

# %%
r.status
# Out:
# 200

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
 
html = urllib.request.urlopen('http://www.uos.ac.kr/main.do').read()
soup = BeautifulSoup(html)
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n <head>\n  <title>\n   서울시립대학교\n  </title>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1.0,  minimum-scale=1.0" name="viewport"/>\n  <link href="/favicon.ico?version=20180828" rel="icon" type="image/x-icon"/>\n  <link href="//www.uos.ac.kr/images/favicon_96.png" rel="shortcut icon" type="image/x-icon"/>\n  <link href="//www.uos.ac.kr/images/favicon_96.png" rel="apple-touch-icon-precomposed"/>\n  <link href="/css/kor2016/style_main_sirip.css?release=20200305" rel="stylesheet" type="text/css"/>\n  <script src="/js/kor2016/lib.min.js">\n  </script>\n  <!-- \t<script  src="/js/kor2016/jquery-1.10.2.min.js"></script> -->\n  <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js">\n  </script>\n  <script src="/js/kor2016/common.js">\n  </script>\n  <script src="/js/kor2016/ui_common.js">\n  </script>\
# ...
